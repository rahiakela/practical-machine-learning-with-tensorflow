# %% [markdown]
# <a href="https://colab.research.google.com/github/rahiakela/practical-machine-learning-with-tensorflow/blob/week-4/overfit_and_underfit.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Explore overfitting and underfitting
#
# As always, the code in this example will use the `tf.keras` API, which you can learn more about in the TensorFlow [Keras guide](https://www.tensorflow.org/guide/keras).
#
# In both of the previous examples—classifying movie reviews and predicting fuel efficiency—we saw that the accuracy of our model on the validation data would peak after training for a number of epochs, and would then start decreasing.
#
# In other words, our model would *overfit* to the training data. Learning how to deal with overfitting is important. Although it's often possible to achieve high accuracy on the *training set*, what we really want is to develop models that generalize well to a *testing set* (or data they haven't seen before).
#
# The opposite of overfitting is *underfitting*. Underfitting occurs when there is still room for improvement on the test data. This can happen for a number of reasons: If the model is not powerful enough, is over-regularized, or has simply not been trained long enough. This means the network has not learned the relevant patterns in the training data.
#
# If you train for too long though, the model will start to overfit and learn patterns from the training data that don't generalize to the test data. We need to strike a balance. Understanding how to train for an appropriate number of epochs as we'll explore below is a useful skill.
#
# To prevent overfitting, the best solution is to use more training data. A model trained on more data will naturally generalize better. When that is no longer possible, the next best solution is to use techniques like regularization. These place constraints on the quantity and type of information your model can store.  If a network can only afford to memorize a small number of patterns, the optimization process will force it to focus on the most prominent patterns, which have a better chance of generalizing well.
#
# In this notebook, we'll explore two common regularization techniques—weight regularization and dropout—and use them to improve our IMDB movie review classification notebook.

# %%
from __future__ import absolute_import, division, print_function, unicode_literals

try:
  # %tensorflow_version only exists in Colab.
  # %tensorflow_version 2.x
except Exception:
  pass
# Out:
# TensorFlow 2.x selected.

# %%
import tensorflow as tf
from tensorflow import keras

import numpy as np
import matplotlib.pyplot as plt

print(tf.__version__)
# Out:
# 2.0.0-rc1

# %% [markdown]
# ## Download the IMDB dataset
#
# Rather than using an embedding as in the previous notebook, here we will multi-hot encode the sentences. This model will quickly overfit to the training set. It will be used to demonstrate when overfitting occurs, and how to fight it.
#
# Multi-hot-encoding our lists means turning them into vectors of 0s and 1s. Concretely, this would mean for instance turning the sequence  `[3, 5]` into a 10,000-dimensional vector that would be all-zeros except for indices 3 and 5, which would be ones.

# %%
NUM_WORDS = 10000

(train_data, train_labels), (test_data, test_labels) = keras.datasets.imdb.load_data(num_words=NUM_WORDS)

def multi_hot_sequences(sequences, dimension):
  # Create an all-zero matrix of shape (len(sequences), dimension)
  results = np.zeros((len(sequences), dimension))
  for i, word_indices in enumerate(sequences):
     results[i, word_indices] = 1.0    # set specific indices of results[i] to 1s
  return results

train_data = multi_hot_sequences(train_data, dimension=NUM_WORDS)
test_data = multi_hot_sequences(test_data, dimension=NUM_WORDS)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/imdb.npz
# 17465344/17464789 [==============================] - 0s 0us/step

# %% [markdown]
# Let's look at one of the resulting multi-hot vectors. The word indices are sorted by frequency, so it is expected that there are more 1-values near index zero, as we can see in this plot:
#
# <img src='https://github.com/rahiakela/img-repo/blob/master/underfitting-and-overfitting-1.JPG?raw=1' width='800'/>

# %%
plt.plot(train_data[0])

# %% [markdown]
# ## Demonstrate overfitting

# %% [markdown]
# The simplest way to prevent overfitting is to reduce the size of the model, i.e. the number of learnable parameters in the model (which is determined by the number of layers and the number of units per layer). In deep learning, the number of learnable parameters in a model is often referred to as the model's "capacity". Intuitively, a model with more parameters will have more "memorization capacity" and therefore will be able to easily learn a perfect dictionary-like mapping between training samples and their targets, a mapping without any generalization power, but this would be useless when making predictions on previously unseen data.
#
# Always keep this in mind: deep learning models tend to be good at fitting to the training data, but the real challenge is generalization, not fitting.
#
# On the other hand, if the network has limited memorization resources, it will not be able to learn the mapping as easily. To minimize its loss, it will have to learn compressed representations that have more predictive power. At the same time, if you make your model too small, it will have difficulty fitting to the training data. There is a balance between "too much capacity" and "not enough capacity".
#
# Unfortunately, there is no magical formula to determine the right size or architecture of your model (in terms of the number of layers, or the right size for each layer). You will have to experiment using a series of different architectures.
#
# To find an appropriate model size, it's best to start with relatively few layers and parameters, then begin increasing the size of the layers or adding new layers until you see diminishing returns on the validation loss. Let's try this on our movie review classification network.
#
# We'll create a simple model using only ```Dense``` layers as a baseline, then create smaller and larger versions, and compare them.

# %% [markdown]
# ## Create a baseline model

# %% [markdown]
# <img src='https://github.com/rahiakela/img-repo/blob/master/underfitting-and-overfitting-base-model.JPG?raw=1' width='800'/>

# %%
baseline_model = keras.Sequential([
    # `input_shape` is only required here so that `.summary` works.
    keras.layers.Dense(16, activation='relu', input_shape=(NUM_WORDS,)),
    keras.layers.Dense(16, activation='relu'),
    keras.layers.Dense(1, activation='sigmoid')
])

baseline_model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy', 'binary_crossentropy'])

baseline_model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_3 (Dense)              (None, 16)                160016
# _________________________________________________________________
# dense_4 (Dense)              (None, 16)                272
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 17
# =================================================================
# Total params: 160,305
# Trainable params: 160,305
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# <img src='https://github.com/rahiakela/img-repo/blob/master/underfitting-and-overfitting-parameters.JPG?raw=1' width='800'/>

# %%
baseline_history = baseline_model.fit(train_data, train_labels, epochs=20, batch_size=512, validation_data=(test_data, test_labels), verbose=2)
# Out:
# Train on 25000 samples, validate on 25000 samples
# Epoch 1/20
# WARNING:tensorflow:From /tensorflow-2.0.0-rc1/python3.6/tensorflow_core/python/ops/nn_impl.py:183: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:Entity <function Function._initialize_uninitialized_variables.<locals>.initialize_variables at 0x7f75e307b158> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: module 'gast' has no attribute 'Num'
# WARNING: Entity <function Function._initialize_uninitialized_variables.<locals>.initialize_variables at 0x7f75e307b158> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: module 'gast' has no attribute 'Num'
# 25000/25000 - 8s - loss: 0.4543 - accuracy: 0.8237 - binary_crossentropy: 0.4543 - val_loss: 0.3213 - val_accuracy: 0.8792 - val_binary_crossentropy: 0.3213
# Epoch 2/20
# 25000/25000 - 3s - loss: 0.2376 - accuracy: 0.9141 - binary_crossentropy: 0.2376 - val_loss: 0.2829 - val_accuracy: 0.8878 - val_binary_crossentropy: 0.2829
# Epoch 3/20
# 25000/25000 - 4s - loss: 0.1761 - accuracy: 0.9386 - binary_crossentropy: 0.1761 - val_loss: 0.2953 - val_accuracy: 0.8824 - val_binary_crossentropy: 0.2953
# Epoch 4/20
# 25000/25000 - 4s - loss: 0.1416 - accuracy: 0.9527 - binary_crossentropy: 0.1416 - val_loss: 0.3200 - val_accuracy: 0.8776 - val_binary_crossentropy: 0.3200
# Epoch 5/20
# 25000/25000 - 4s - loss: 0.1167 - accuracy: 0.9616 - binary_crossentropy: 0.1167 - val_loss: 0.3474 - val_accuracy: 0.8734 - val_binary_crossentropy: 0.3474
# Epoch 6/20
# 25000/25000 - 4s - loss: 0.0972 - accuracy: 0.9696 - binary_crossentropy: 0.0972 - val_loss: 0.3980 - val_accuracy: 0.8646 - val_binary_crossentropy: 0.3980
# Epoch 7/20
# 25000/25000 - 4s - loss: 0.0809 - accuracy: 0.9752 - binary_crossentropy: 0.0809 - val_loss: 0.4238 - val_accuracy: 0.8643 - val_binary_crossentropy: 0.4238
# Epoch 8/20
# 25000/25000 - 4s - loss: 0.0669 - accuracy: 0.9820 - binary_crossentropy: 0.0669 - val_loss: 0.4660 - val_accuracy: 0.8603 - val_binary_crossentropy: 0.4660
# Epoch 9/20
# 25000/25000 - 4s - loss: 0.0550 - accuracy: 0.9864 - binary_crossentropy: 0.0550 - val_loss: 0.5065 - val_accuracy: 0.8586 - val_binary_crossentropy: 0.5065
# Epoch 10/20
# 25000/25000 - 4s - loss: 0.0451 - accuracy: 0.9898 - binary_crossentropy: 0.0451 - val_loss: 0.5531 - val_accuracy: 0.8573 - val_binary_crossentropy: 0.5531
# Epoch 11/20
# 25000/25000 - 4s - loss: 0.0364 - accuracy: 0.9923 - binary_crossentropy: 0.0364 - val_loss: 0.6022 - val_accuracy: 0.8542 - val_binary_crossentropy: 0.6022
# Epoch 12/20
# 25000/25000 - 4s - loss: 0.0323 - accuracy: 0.9930 - binary_crossentropy: 0.0323 - val_loss: 0.6567 - val_accuracy: 0.8524 - val_binary_crossentropy: 0.6567
# Epoch 13/20
# 25000/25000 - 4s - loss: 0.0260 - accuracy: 0.9954 - binary_crossentropy: 0.0260 - val_loss: 0.7033 - val_accuracy: 0.8508 - val_binary_crossentropy: 0.7033
# Epoch 14/20
# 25000/25000 - 3s - loss: 0.0210 - accuracy: 0.9972 - binary_crossentropy: 0.0210 - val_loss: 0.7416 - val_accuracy: 0.8505 - val_binary_crossentropy: 0.7416
# Epoch 15/20
# 25000/25000 - 4s - loss: 0.0156 - accuracy: 0.9986 - binary_crossentropy: 0.0156 - val_loss: 0.7820 - val_accuracy: 0.8494 - val_binary_crossentropy: 0.7820
# Epoch 16/20
# 25000/25000 - 3s - loss: 0.0115 - accuracy: 0.9994 - binary_crossentropy: 0.0115 - val_loss: 0.8218 - val_accuracy: 0.8484 - val_binary_crossentropy: 0.8218
# Epoch 17/20
# 25000/25000 - 3s - loss: 0.0089 - accuracy: 0.9996 - binary_crossentropy: 0.0089 - val_loss: 0.8596 - val_accuracy: 0.8481 - val_binary_crossentropy: 0.8596
# Epoch 18/20
# 25000/25000 - 3s - loss: 0.0072 - accuracy: 0.9999 - binary_crossentropy: 0.0072 - val_loss: 0.8949 - val_accuracy: 0.8478 - val_binary_crossentropy: 0.8949
# Epoch 19/20
# 25000/25000 - 3s - loss: 0.0059 - accuracy: 0.9999 - binary_crossentropy: 0.0059 - val_loss: 0.9237 - val_accuracy: 0.8474 - val_binary_crossentropy: 0.9237
# Epoch 20/20
# 25000/25000 - 3s - loss: 0.0050 - accuracy: 1.0000 - binary_crossentropy: 0.0050 - val_loss: 0.9562 - val_accuracy: 0.8476 - val_binary_crossentropy: 0.9562

# %% [markdown]
# ### Create a smaller model
#
# Let's create a model with less hidden units to compare against the baseline model that we just created:

# %%
smaller_model = keras.Sequential([
    # `input_shape` is only required here so that `.summary` works.
    keras.layers.Dense(4, activation='relu', input_shape=(NUM_WORDS,)),
    keras.layers.Dense(4, activation='relu'),
    keras.layers.Dense(1, activation='sigmoid')
])

smaller_model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy', 'binary_crossentropy'])

smaller_model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_6 (Dense)              (None, 4)                 40004
# _________________________________________________________________
# dense_7 (Dense)              (None, 4)                 20
# _________________________________________________________________
# dense_8 (Dense)              (None, 1)                 5
# =================================================================
# Total params: 40,029
# Trainable params: 40,029
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# And train the model using the same data:

# %%
smaller_history = smaller_model.fit(train_data, train_labels, epochs=20, batch_size=512, validation_data=(test_data, test_labels), verbose=2)
# Out:
# Train on 25000 samples, validate on 25000 samples
# Epoch 1/20
# WARNING:tensorflow:Entity <function Function._initialize_uninitialized_variables.<locals>.initialize_variables at 0x7f75dc43c488> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: module 'gast' has no attribute 'Num'
# WARNING: Entity <function Function._initialize_uninitialized_variables.<locals>.initialize_variables at 0x7f75dc43c488> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: module 'gast' has no attribute 'Num'
# 25000/25000 - 4s - loss: 0.6369 - accuracy: 0.7155 - binary_crossentropy: 0.6369 - val_loss: 0.5602 - val_accuracy: 0.8482 - val_binary_crossentropy: 0.5602
# Epoch 2/20
# 25000/25000 - 3s - loss: 0.4606 - accuracy: 0.8810 - binary_crossentropy: 0.4606 - val_loss: 0.4105 - val_accuracy: 0.8757 - val_binary_crossentropy: 0.4105
# Epoch 3/20
# 25000/25000 - 4s - loss: 0.3315 - accuracy: 0.9079 - binary_crossentropy: 0.3315 - val_loss: 0.3363 - val_accuracy: 0.8854 - val_binary_crossentropy: 0.3363
# Epoch 4/20
# 25000/25000 - 4s - loss: 0.2626 - accuracy: 0.9203 - binary_crossentropy: 0.2626 - val_loss: 0.3030 - val_accuracy: 0.8894 - val_binary_crossentropy: 0.3030
# Epoch 5/20
# 25000/25000 - 4s - loss: 0.2217 - accuracy: 0.9311 - binary_crossentropy: 0.2217 - val_loss: 0.2883 - val_accuracy: 0.8899 - val_binary_crossentropy: 0.2883
# Epoch 6/20
# 25000/25000 - 3s - loss: 0.1949 - accuracy: 0.9385 - binary_crossentropy: 0.1949 - val_loss: 0.2852 - val_accuracy: 0.8872 - val_binary_crossentropy: 0.2852
# Epoch 7/20
# 25000/25000 - 3s - loss: 0.1739 - accuracy: 0.9445 - binary_crossentropy: 0.1739 - val_loss: 0.2831 - val_accuracy: 0.8868 - val_binary_crossentropy: 0.2831
# Epoch 8/20
# 25000/25000 - 4s - loss: 0.1577 - accuracy: 0.9503 - binary_crossentropy: 0.1577 - val_loss: 0.2869 - val_accuracy: 0.8858 - val_binary_crossentropy: 0.2869
# Epoch 9/20
# 25000/25000 - 3s - loss: 0.1439 - accuracy: 0.9558 - binary_crossentropy: 0.1439 - val_loss: 0.2924 - val_accuracy: 0.8839 - val_binary_crossentropy: 0.2924
# Epoch 10/20
# 25000/25000 - 3s - loss: 0.1325 - accuracy: 0.9600 - binary_crossentropy: 0.1325 - val_loss: 0.3002 - val_accuracy: 0.8820 - val_binary_crossentropy: 0.3002
# Epoch 11/20
# 25000/25000 - 3s - loss: 0.1226 - accuracy: 0.9635 - binary_crossentropy: 0.1226 - val_loss: 0.3122 - val_accuracy: 0.8793 - val_binary_crossentropy: 0.3122
# Epoch 12/20
# 25000/25000 - 4s - loss: 0.1142 - accuracy: 0.9669 - binary_crossentropy: 0.1142 - val_loss: 0.3227 - val_accuracy: 0.8767 - val_binary_crossentropy: 0.3227
# Epoch 13/20
# 25000/25000 - 4s - loss: 0.1056 - accuracy: 0.9692 - binary_crossentropy: 0.1056 - val_loss: 0.3272 - val_accuracy: 0.8774 - val_binary_crossentropy: 0.3272
# Epoch 14/20
# 25000/25000 - 3s - loss: 0.0978 - accuracy: 0.9730 - binary_crossentropy: 0.0978 - val_loss: 0.3401 - val_accuracy: 0.8753 - val_binary_crossentropy: 0.3401
# Epoch 15/20
# 25000/25000 - 3s - loss: 0.0910 - accuracy: 0.9755 - binary_crossentropy: 0.0910 - val_loss: 0.3505 - val_accuracy: 0.8729 - val_binary_crossentropy: 0.3505
# Epoch 16/20
# 25000/25000 - 3s - loss: 0.0850 - accuracy: 0.9774 - binary_crossentropy: 0.0850 - val_loss: 0.3618 - val_accuracy: 0.8719 - val_binary_crossentropy: 0.3618
# Epoch 17/20
# 25000/25000 - 3s - loss: 0.0790 - accuracy: 0.9803 - binary_crossentropy: 0.0790 - val_loss: 0.3746 - val_accuracy: 0.8701 - val_binary_crossentropy: 0.3746
# Epoch 18/20
# 25000/25000 - 3s - loss: 0.0734 - accuracy: 0.9830 - binary_crossentropy: 0.0734 - val_loss: 0.3885 - val_accuracy: 0.8684 - val_binary_crossentropy: 0.3885
# Epoch 19/20
# 25000/25000 - 3s - loss: 0.0684 - accuracy: 0.9847 - binary_crossentropy: 0.0684 - val_loss: 0.4035 - val_accuracy: 0.8671 - val_binary_crossentropy: 0.4035
# Epoch 20/20
# 25000/25000 - 3s - loss: 0.0637 - accuracy: 0.9863 - binary_crossentropy: 0.0637 - val_loss: 0.4157 - val_accuracy: 0.8670 - val_binary_crossentropy: 0.4157

# %% [markdown]
# ### Create a bigger model
#
# As an exercise, you can create an even larger model, and see how quickly it begins overfitting.  Next, let's add to this benchmark a network that has much more capacity, far more than the problem would warrant:

# %%
bigger_model = keras.Sequential([
    # `input_shape` is only required here so that `.summary` works.
    keras.layers.Dense(512, activation='relu', input_shape=(NUM_WORDS,)),
    keras.layers.Dense(512, activation='relu'),
    keras.layers.Dense(1, activation='sigmoid')
])

bigger_model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy', 'binary_crossentropy'])

bigger_model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_9 (Dense)              (None, 512)               5120512
# _________________________________________________________________
# dense_10 (Dense)             (None, 512)               262656
# _________________________________________________________________
# dense_11 (Dense)             (None, 1)                 513
# =================================================================
# Total params: 5,383,681
# Trainable params: 5,383,681
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# And, again, train the model using the same data:

# %%
bigger_history = bigger_model.fit(train_data, train_labels, epochs=20, batch_size=512, validation_data=(test_data, test_labels), verbose=2)
# Out:
# Train on 25000 samples, validate on 25000 samples
# Epoch 1/20
# WARNING:tensorflow:Entity <function Function._initialize_uninitialized_variables.<locals>.initialize_variables at 0x7f75dc45e400> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: module 'gast' has no attribute 'Num'
# WARNING: Entity <function Function._initialize_uninitialized_variables.<locals>.initialize_variables at 0x7f75dc45e400> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: module 'gast' has no attribute 'Num'
# 25000/25000 - 20s - loss: 0.3419 - accuracy: 0.8532 - binary_crossentropy: 0.3419 - val_loss: 0.2920 - val_accuracy: 0.8812 - val_binary_crossentropy: 0.2920
# Epoch 2/20
# 25000/25000 - 18s - loss: 0.1371 - accuracy: 0.9487 - binary_crossentropy: 0.1371 - val_loss: 0.3323 - val_accuracy: 0.8732 - val_binary_crossentropy: 0.3323
# Epoch 3/20
# 25000/25000 - 18s - loss: 0.0434 - accuracy: 0.9880 - binary_crossentropy: 0.0434 - val_loss: 0.4441 - val_accuracy: 0.8668 - val_binary_crossentropy: 0.4441
# Epoch 4/20
# 25000/25000 - 18s - loss: 0.0065 - accuracy: 0.9991 - binary_crossentropy: 0.0065 - val_loss: 0.5961 - val_accuracy: 0.8688 - val_binary_crossentropy: 0.5961
# Epoch 5/20
# 25000/25000 - 18s - loss: 0.0017 - accuracy: 1.0000 - binary_crossentropy: 0.0017 - val_loss: 0.6713 - val_accuracy: 0.8698 - val_binary_crossentropy: 0.6713
# Epoch 6/20
# 25000/25000 - 19s - loss: 2.4796e-04 - accuracy: 1.0000 - binary_crossentropy: 2.4796e-04 - val_loss: 0.7322 - val_accuracy: 0.8713 - val_binary_crossentropy: 0.7322
# Epoch 7/20
# 25000/25000 - 19s - loss: 1.3742e-04 - accuracy: 1.0000 - binary_crossentropy: 1.3742e-04 - val_loss: 0.7714 - val_accuracy: 0.8714 - val_binary_crossentropy: 0.7714
# Epoch 8/20
# 25000/25000 - 19s - loss: 9.2723e-05 - accuracy: 1.0000 - binary_crossentropy: 9.2723e-05 - val_loss: 0.8007 - val_accuracy: 0.8715 - val_binary_crossentropy: 0.8007
# Epoch 9/20
# 25000/25000 - 19s - loss: 6.7391e-05 - accuracy: 1.0000 - binary_crossentropy: 6.7391e-05 - val_loss: 0.8272 - val_accuracy: 0.8715 - val_binary_crossentropy: 0.8272
# Epoch 10/20
# 25000/25000 - 20s - loss: 5.1044e-05 - accuracy: 1.0000 - binary_crossentropy: 5.1044e-05 - val_loss: 0.8495 - val_accuracy: 0.8711 - val_binary_crossentropy: 0.8495
# Epoch 11/20
# 25000/25000 - 19s - loss: 3.9918e-05 - accuracy: 1.0000 - binary_crossentropy: 3.9918e-05 - val_loss: 0.8695 - val_accuracy: 0.8716 - val_binary_crossentropy: 0.8695
# Epoch 12/20
# 25000/25000 - 18s - loss: 3.1843e-05 - accuracy: 1.0000 - binary_crossentropy: 3.1843e-05 - val_loss: 0.8877 - val_accuracy: 0.8717 - val_binary_crossentropy: 0.8877
# Epoch 13/20
# 25000/25000 - 18s - loss: 2.6003e-05 - accuracy: 1.0000 - binary_crossentropy: 2.6003e-05 - val_loss: 0.9046 - val_accuracy: 0.8718 - val_binary_crossentropy: 0.9046
# Epoch 14/20
# 25000/25000 - 19s - loss: 2.1479e-05 - accuracy: 1.0000 - binary_crossentropy: 2.1479e-05 - val_loss: 0.9197 - val_accuracy: 0.8719 - val_binary_crossentropy: 0.9197
# Epoch 15/20
# 25000/25000 - 18s - loss: 1.8031e-05 - accuracy: 1.0000 - binary_crossentropy: 1.8031e-05 - val_loss: 0.9359 - val_accuracy: 0.8719 - val_binary_crossentropy: 0.9359
# Epoch 16/20
# 25000/25000 - 19s - loss: 1.5304e-05 - accuracy: 1.0000 - binary_crossentropy: 1.5304e-05 - val_loss: 0.9490 - val_accuracy: 0.8718 - val_binary_crossentropy: 0.9490
# Epoch 17/20
# 25000/25000 - 19s - loss: 1.3158e-05 - accuracy: 1.0000 - binary_crossentropy: 1.3158e-05 - val_loss: 0.9615 - val_accuracy: 0.8718 - val_binary_crossentropy: 0.9615
# Epoch 18/20
# 25000/25000 - 18s - loss: 1.1386e-05 - accuracy: 1.0000 - binary_crossentropy: 1.1386e-05 - val_loss: 0.9747 - val_accuracy: 0.8718 - val_binary_crossentropy: 0.9747
# Epoch 19/20
# 25000/25000 - 18s - loss: 9.9400e-06 - accuracy: 1.0000 - binary_crossentropy: 9.9400e-06 - val_loss: 0.9862 - val_accuracy: 0.8718 - val_binary_crossentropy: 0.9862
# Epoch 20/20
# 25000/25000 - 18s - loss: 8.7476e-06 - accuracy: 1.0000 - binary_crossentropy: 8.7476e-06 - val_loss: 0.9971 - val_accuracy: 0.8717 - val_binary_crossentropy: 0.9971

# %% [markdown]
# ### Plot the training and validation loss
#
# <!--TODO(markdaoust): This should be a one-liner with tensorboard -->
#
# The solid lines show the training loss, and the dashed lines show the validation loss (remember: a lower validation loss indicates a better model). Here, the smaller network begins overfitting later than the baseline model (after 6 epochs rather than 4) and its performance degrades much more slowly once it starts overfitting.

# %%
def plot_history(histories, key='binary_crossentropy'):
  plt.figure(figsize=(16, 10))

  for name, history in histories:
    val = plt.plot(history.epoch, history.history['val_'+key], '--', label=name.title() + ' Val')
    plt.plot(history.epoch, history.history[key], color=val[0].get_color(), label=name.title() + ' Train')

  plt.xlabel('Epochs')
  plt.ylabel(key.replace('_', '').title())
  plt.legend()

  plt.xlim([0, max(history.epoch)])

plot_history([('baseline', baseline_history), ('smaller', smaller_history), ('bigger', bigger_history)])

# %% [markdown]
# Notice that the larger network begins overfitting almost right away, after just one epoch, and overfits much more severely. The more capacity the network has, the quicker it will be able to model the training data (resulting in a low training loss), but the more susceptible it is to overfitting (resulting in a large difference between the training and validation loss).
#
# ## Strategies to prevent overfitting
#
# ### Add weight regularization
#
# You may be familiar with Occam's Razor principle: given two explanations for something, the explanation most likely to be correct is the "simplest" one, the one that makes the least amount of assumptions. This also applies to the models learned by neural networks: given some training data and a network architecture, there are multiple sets of weights values (multiple models) that could explain the data, and simpler models are less likely to overfit than complex ones.
#
# A "simple model" in this context is a model where the distribution of parameter values has less entropy (or a model with fewer parameters altogether, as we saw in the section above). Thus a common way to mitigate overfitting is to put constraints on the complexity of a network by forcing its weights only to take small values, which makes the distribution of weight values more "regular". This is called "weight regularization", and it is done by adding to the loss function of the network a cost associated with having large weights. This cost comes in two flavors:
#
# * [L1 regularization](https://developers.google.com/machine-learning/glossary/#L1_regularization), where the cost added is proportional to the absolute value of the weights coefficients (i.e. to what is called the "L1 norm" of the weights).
#
# * [L2 regularization](https://developers.google.com/machine-learning/glossary/#L2_regularization), where the cost added is proportional to the square of the value of the weights coefficients (i.e. to what is called the squared "L2 norm" of the weights). L2 regularization is also called weight decay in the context of neural networks. Don't let the different name confuse you: weight decay is mathematically the exact same as L2 regularization.
#
# L1 regularization introduces sparsity to make some of your weight parameters zero. L2 regularization will penalize the weights parameters without making them sparse—one reason why L2 is more common.
#
# <img src='https://github.com/rahiakela/img-repo/blob/master/underfitting-and-overfitting-penalty.JPG?raw=1' width='800'/>
#
# In `tf.keras`, weight regularization is added by passing weight regularizer instances to layers as keyword arguments. Let's add L2 weight regularization now.

# %%
l2_model = keras.Sequential([
    keras.layers.Dense(16, kernel_regularizer=keras.regularizers.l2(0.001), activation='relu', input_shape=(NUM_WORDS,)),
    keras.layers.Dense(16, kernel_regularizer=keras.regularizers.l2(0.001), activation='relu'),
    keras.layers.Dense(1, activation='sigmoid')
])

l2_model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy', 'binary_crossentropy'])

l2_model_history = l2_model.fit(train_data, train_labels, epochs=20, batch_size=512, validation_data=(test_data, test_labels), verbose=2)
# Out:
# Train on 25000 samples, validate on 25000 samples
# Epoch 1/20
# WARNING:tensorflow:Entity <function Function._initialize_uninitialized_variables.<locals>.initialize_variables at 0x7f75d515c2f0> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: module 'gast' has no attribute 'Num'
# WARNING: Entity <function Function._initialize_uninitialized_variables.<locals>.initialize_variables at 0x7f75d515c2f0> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: module 'gast' has no attribute 'Num'
# 25000/25000 - 6s - loss: 0.5472 - accuracy: 0.7888 - binary_crossentropy: 0.5083 - val_loss: 0.3913 - val_accuracy: 0.8744 - val_binary_crossentropy: 0.3500
# Epoch 2/20
# 25000/25000 - 3s - loss: 0.3123 - accuracy: 0.9061 - binary_crossentropy: 0.2658 - val_loss: 0.3353 - val_accuracy: 0.8876 - val_binary_crossentropy: 0.2852
# Epoch 3/20
# 25000/25000 - 3s - loss: 0.2573 - accuracy: 0.9275 - binary_crossentropy: 0.2045 - val_loss: 0.3377 - val_accuracy: 0.8855 - val_binary_crossentropy: 0.2830
# Epoch 4/20
# 25000/25000 - 3s - loss: 0.2332 - accuracy: 0.9402 - binary_crossentropy: 0.1766 - val_loss: 0.3555 - val_accuracy: 0.8797 - val_binary_crossentropy: 0.2976
# Epoch 5/20
# 25000/25000 - 3s - loss: 0.2185 - accuracy: 0.9458 - binary_crossentropy: 0.1593 - val_loss: 0.3648 - val_accuracy: 0.8784 - val_binary_crossentropy: 0.3048
# Epoch 6/20
# 25000/25000 - 3s - loss: 0.2070 - accuracy: 0.9505 - binary_crossentropy: 0.1461 - val_loss: 0.3814 - val_accuracy: 0.8746 - val_binary_crossentropy: 0.3198
# Epoch 7/20
# 25000/25000 - 3s - loss: 0.1976 - accuracy: 0.9544 - binary_crossentropy: 0.1353 - val_loss: 0.3927 - val_accuracy: 0.8737 - val_binary_crossentropy: 0.3301
# Epoch 8/20
# 25000/25000 - 4s - loss: 0.1913 - accuracy: 0.9564 - binary_crossentropy: 0.1280 - val_loss: 0.4109 - val_accuracy: 0.8695 - val_binary_crossentropy: 0.3472
# Epoch 9/20
# 25000/25000 - 4s - loss: 0.1840 - accuracy: 0.9589 - binary_crossentropy: 0.1198 - val_loss: 0.4251 - val_accuracy: 0.8677 - val_binary_crossentropy: 0.3604
# Epoch 10/20
# 25000/25000 - 4s - loss: 0.1779 - accuracy: 0.9628 - binary_crossentropy: 0.1127 - val_loss: 0.4312 - val_accuracy: 0.8670 - val_binary_crossentropy: 0.3658
# Epoch 11/20
# 25000/25000 - 4s - loss: 0.1742 - accuracy: 0.9642 - binary_crossentropy: 0.1083 - val_loss: 0.4484 - val_accuracy: 0.8639 - val_binary_crossentropy: 0.3822
# Epoch 12/20
# 25000/25000 - 4s - loss: 0.1684 - accuracy: 0.9652 - binary_crossentropy: 0.1018 - val_loss: 0.4643 - val_accuracy: 0.8638 - val_binary_crossentropy: 0.3973
# Epoch 13/20
# 25000/25000 - 4s - loss: 0.1651 - accuracy: 0.9673 - binary_crossentropy: 0.0977 - val_loss: 0.4753 - val_accuracy: 0.8621 - val_binary_crossentropy: 0.4078
# Epoch 14/20
# 25000/25000 - 4s - loss: 0.1617 - accuracy: 0.9677 - binary_crossentropy: 0.0939 - val_loss: 0.4931 - val_accuracy: 0.8613 - val_binary_crossentropy: 0.4249
# Epoch 15/20
# 25000/25000 - 4s - loss: 0.1581 - accuracy: 0.9702 - binary_crossentropy: 0.0893 - val_loss: 0.4990 - val_accuracy: 0.8606 - val_binary_crossentropy: 0.4300
# Epoch 16/20
# 25000/25000 - 4s - loss: 0.1530 - accuracy: 0.9728 - binary_crossentropy: 0.0838 - val_loss: 0.5059 - val_accuracy: 0.8587 - val_binary_crossentropy: 0.4366
# Epoch 17/20
# 25000/25000 - 4s - loss: 0.1488 - accuracy: 0.9750 - binary_crossentropy: 0.0795 - val_loss: 0.5184 - val_accuracy: 0.8562 - val_binary_crossentropy: 0.4491
# Epoch 18/20
# 25000/25000 - 4s - loss: 0.1464 - accuracy: 0.9748 - binary_crossentropy: 0.0768 - val_loss: 0.5270 - val_accuracy: 0.8582 - val_binary_crossentropy: 0.4570
# Epoch 19/20
# 25000/25000 - 4s - loss: 0.1430 - accuracy: 0.9768 - binary_crossentropy: 0.0727 - val_loss: 0.5460 - val_accuracy: 0.8540 - val_binary_crossentropy: 0.4754
# Epoch 20/20
# 25000/25000 - 4s - loss: 0.1423 - accuracy: 0.9768 - binary_crossentropy: 0.0717 - val_loss: 0.5617 - val_accuracy: 0.8563 - val_binary_crossentropy: 0.4908

# %% [markdown]
# ```l2(0.001)``` means that every coefficient in the weight matrix of the layer will add ```0.001 * weight_coefficient_value**2``` to the total loss of the network. Note that because this penalty is only added at training time, the loss for this network will be much higher at training than at test time.
#
# Here's the impact of our L2 regularization penalty:

# %%
plot_history([('baseline', baseline_history), ('l2', l2_model_history)])

# %% [markdown]
# As you can see, the L2 regularized model has become much more resistant to overfitting than the baseline model, even though both models have the same number of parameters.

# %% [markdown]
# ### Add dropout
#
# Dropout is one of the most effective and most commonly used regularization techniques for neural networks, developed by Hinton and his students at the University of Toronto. Dropout, applied to a layer, consists of randomly "dropping out" (i.e. set to zero) a number of output features of the layer during training. Let's say a given layer would normally have returned a vector [0.2, 0.5, 1.3, 0.8, 1.1] for a given input sample during training; after applying dropout, this vector will have a few zero entries distributed at random, e.g. [0, 0.5,
# 1.3, 0, 1.1]. The "dropout rate" is the fraction of the features that are being zeroed-out; it is usually set between 0.2 and 0.5. At test time, no units are dropped out, and instead the layer's output values are scaled down by a factor equal to the dropout rate, so as to balance for the fact that more units are active than at training time.
#
# In tf.keras you can introduce dropout in a network via the Dropout layer, which gets applied to the output of layer right before.
#
# Let's add two Dropout layers in our IMDB network to see how well they do at reducing overfitting:

# %%
dpt_model = keras.Sequential([
    # `input_shape` is only required here so that `.summary` works.
    keras.layers.Dense(16, activation='relu', input_shape=(NUM_WORDS,)),
    keras.layers.Dropout(0.5),
    keras.layers.Dense(16, activation='relu'),
    keras.layers.Dropout(0.5),
    keras.layers.Dense(1, activation='sigmoid')
])

dpt_model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy', 'binary_crossentropy'])

dpt_model_history = dpt_model.fit(train_data, train_labels, epochs=20, batch_size=512, validation_data=(test_data, test_labels), verbose=2)
# Out:
# Train on 25000 samples, validate on 25000 samples
# Epoch 1/20
# WARNING:tensorflow:Entity <function Function._initialize_uninitialized_variables.<locals>.initialize_variables at 0x7f75d4087d90> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: module 'gast' has no attribute 'Num'
# WARNING: Entity <function Function._initialize_uninitialized_variables.<locals>.initialize_variables at 0x7f75d4087d90> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: module 'gast' has no attribute 'Num'
# 25000/25000 - 6s - loss: 0.6153 - accuracy: 0.6535 - binary_crossentropy: 0.6153 - val_loss: 0.4583 - val_accuracy: 0.8566 - val_binary_crossentropy: 0.4583
# Epoch 2/20
# 25000/25000 - 4s - loss: 0.4347 - accuracy: 0.8186 - binary_crossentropy: 0.4347 - val_loss: 0.3180 - val_accuracy: 0.8823 - val_binary_crossentropy: 0.3180
# Epoch 3/20
# 25000/25000 - 3s - loss: 0.3355 - accuracy: 0.8730 - binary_crossentropy: 0.3355 - val_loss: 0.2809 - val_accuracy: 0.8880 - val_binary_crossentropy: 0.2809
# Epoch 4/20
# 25000/25000 - 3s - loss: 0.2778 - accuracy: 0.8976 - binary_crossentropy: 0.2778 - val_loss: 0.2732 - val_accuracy: 0.8884 - val_binary_crossentropy: 0.2732
# Epoch 5/20
# 25000/25000 - 3s - loss: 0.2395 - accuracy: 0.9152 - binary_crossentropy: 0.2395 - val_loss: 0.2754 - val_accuracy: 0.8897 - val_binary_crossentropy: 0.2754
# Epoch 6/20
# 25000/25000 - 3s - loss: 0.2124 - accuracy: 0.9253 - binary_crossentropy: 0.2124 - val_loss: 0.2861 - val_accuracy: 0.8872 - val_binary_crossentropy: 0.2861
# Epoch 7/20
# 25000/25000 - 3s - loss: 0.1858 - accuracy: 0.9349 - binary_crossentropy: 0.1858 - val_loss: 0.3049 - val_accuracy: 0.8837 - val_binary_crossentropy: 0.3049
# Epoch 8/20
# 25000/25000 - 4s - loss: 0.1685 - accuracy: 0.9420 - binary_crossentropy: 0.1685 - val_loss: 0.3202 - val_accuracy: 0.8835 - val_binary_crossentropy: 0.3202
# Epoch 9/20
# 25000/25000 - 4s - loss: 0.1538 - accuracy: 0.9476 - binary_crossentropy: 0.1538 - val_loss: 0.3440 - val_accuracy: 0.8826 - val_binary_crossentropy: 0.3440
# Epoch 10/20
# 25000/25000 - 4s - loss: 0.1383 - accuracy: 0.9529 - binary_crossentropy: 0.1383 - val_loss: 0.3524 - val_accuracy: 0.8804 - val_binary_crossentropy: 0.3524
# Epoch 11/20
# 25000/25000 - 4s - loss: 0.1254 - accuracy: 0.9572 - binary_crossentropy: 0.1254 - val_loss: 0.3809 - val_accuracy: 0.8790 - val_binary_crossentropy: 0.3809
# Epoch 12/20
# 25000/25000 - 4s - loss: 0.1153 - accuracy: 0.9592 - binary_crossentropy: 0.1153 - val_loss: 0.3969 - val_accuracy: 0.8784 - val_binary_crossentropy: 0.3969
# Epoch 13/20
# 25000/25000 - 4s - loss: 0.1065 - accuracy: 0.9605 - binary_crossentropy: 0.1065 - val_loss: 0.4275 - val_accuracy: 0.8787 - val_binary_crossentropy: 0.4275
# Epoch 14/20
# 25000/25000 - 4s - loss: 0.1022 - accuracy: 0.9611 - binary_crossentropy: 0.1022 - val_loss: 0.4302 - val_accuracy: 0.8780 - val_binary_crossentropy: 0.4302
# Epoch 15/20
# 25000/25000 - 4s - loss: 0.0949 - accuracy: 0.9652 - binary_crossentropy: 0.0949 - val_loss: 0.4782 - val_accuracy: 0.8772 - val_binary_crossentropy: 0.4782
# Epoch 16/20
# 25000/25000 - 4s - loss: 0.0888 - accuracy: 0.9666 - binary_crossentropy: 0.0888 - val_loss: 0.4718 - val_accuracy: 0.8775 - val_binary_crossentropy: 0.4718
# Epoch 17/20
# 25000/25000 - 4s - loss: 0.0822 - accuracy: 0.9688 - binary_crossentropy: 0.0822 - val_loss: 0.4991 - val_accuracy: 0.8765 - val_binary_crossentropy: 0.4991
# Epoch 18/20
# 25000/25000 - 4s - loss: 0.0761 - accuracy: 0.9711 - binary_crossentropy: 0.0761 - val_loss: 0.5497 - val_accuracy: 0.8755 - val_binary_crossentropy: 0.5497
# Epoch 19/20
# 25000/25000 - 3s - loss: 0.0743 - accuracy: 0.9705 - binary_crossentropy: 0.0743 - val_loss: 0.5569 - val_accuracy: 0.8738 - val_binary_crossentropy: 0.5569
# Epoch 20/20
# 25000/25000 - 3s - loss: 0.0675 - accuracy: 0.9720 - binary_crossentropy: 0.0675 - val_loss: 0.5683 - val_accuracy: 0.8749 - val_binary_crossentropy: 0.5683

# %%
plot_history([('baseline', baseline_history), ('dropout', dpt_model_history)])

# %% [markdown]
# Adding dropout is a clear improvement over the baseline model.
#
# To recap: here are the most common ways to prevent overfitting in neural networks:
#
# * Get more training data.
# * Reduce the capacity of the network.
# * Add weight regularization.
# * Add dropout.
#
# And two important approaches not covered in this guide are data-augmentation and batch normalization.
